# %% [markdown]
# # Milestone #2: Final Project
# ## Zachary Kruse
# ### 4/22/2025

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configure visual settings
# %matplotlib inline
sns.set(style="whitegrid")

# %%
# Load the dataset
df = pd.read_csv('listings.csv')

# Display the first few rows
df.head()
# Out:
#         id                         listing_url     scrape_id last_scraped  \
# 0  36121.0  https://www.airbnb.com/rooms/36121  2.025030e+13     3/3/2025
# 1  36647.0  https://www.airbnb.com/rooms/36647  2.025030e+13     3/3/2025
# 2  38663.0  https://www.airbnb.com/rooms/38663  2.025030e+13     3/2/2025
# 3  38833.0  https://www.airbnb.com/rooms/38833  2.025030e+13     3/3/2025
# 4  39282.0  https://www.airbnb.com/rooms/39282  2.025030e+13     3/2/2025
#
#         source                                               name  \
# 0  city scrape                 Lg Rm in Historic Prospect Heights
# 1  city scrape  1 Bedroom & your own Bathroom, Elevator Apartment
# 2  city scrape                   Luxury Brownstone in Boerum Hill
# 3  city scrape                 Spectacular West Harlem Garden Apt
# 4  city scrape                    “Work-from-home” from OUR home.
#
#                                          description  \
# 0  Cozy space share in the heart of a great neigh...
# 1  Private bedroom with your own bathroom in a 2 ...
# 2  Beautiful, large home in great hipster neighbo...
# 3  This is a very large and unique  space. An inc...
# 4  *Monthly Discount will automatically apply <br...
#
#                                neighborhood_overview  \
# 0  Full of tree-lined streets and beautiful brown...
# 1   Manhattan, SE corner of 2nd Ave/ E. 110th street
# 2  diverse, lively, hip, cool: loaded with restau...
# 3  West Harlem is now packed with great restauran...
# 4  THE NEIGHBORHOOD:<br />Our apartment is locate...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/8776354/35b32...    62165  ...
# 1  https://a0.muscache.com/pictures/miso/Hosting-...   157798  ...
# 2  https://a0.muscache.com/pictures/miso/Hosting-...   165789  ...
# 3  https://a0.muscache.com/pictures/7554f9e5-4ab0...   166532  ...
# 4  https://a0.muscache.com/pictures/ef8f43ad-d967...   168525  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        5.00                   5.00                5.00
# 1                        4.90                   4.38                4.71
# 2                        4.88                   4.86                4.62
# 3                        4.96                   4.79                4.82
# 4                        4.88                   4.85                4.78
#
#               license instant_bookable calculated_host_listings_count  \
# 0                 NaN                f                              1
# 1                 NaN                f                              1
# 2  OSE-STRREG-0001784                f                              1
# 3  OSE-STRREG-0000476                f                              1
# 4  OSE-STRREG-0001150                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           1
# 4                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            1
# 2                                            1
# 3                                            0
# 4                                            2
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.05
# 1                                           0              0.58
# 2                                           0              0.28
# 3                                           0              1.36
# 4                                           0              1.54
#
# [5 rows x 79 columns]

# %%
# Check the dimensions of the dataset
print("Shape of the dataset:", df.shape)
# Out:
# Shape of the dataset: (37434, 79)

# %%
# Display the column names
print("\nColumn names:")
print(df.columns.tolist())
# Out:
# Column names:
# ['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name', 'description', 'neighborhood_overview', 'picture_url', 'host_id', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude', 'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'calendar_last_scraped', 'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d', 'availability_eoy', 'number_of_reviews_ly', 'estimated_occupancy_l365d', 'estimated_revenue_l365d', 'first_review', 'last_review', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'license', 'instant_bookable', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'reviews_per_month']

# %%
# Data types of each column
print("\nData types:")
print(df.dtypes)
# Out:
# Data types:
# id                                              float64
# listing_url                                      object
# scrape_id                                       float64
# last_scraped                                     object
# source                                           object
#                                                  ...
# calculated_host_listings_count                    int64
# calculated_host_listings_count_entire_homes       int64
# calculated_host_listings_count_private_rooms      int64
# calculated_host_listings_count_shared_rooms       int64
# reviews_per_month                               float64
# Length: 79, dtype: object

# %%
# Display basic statistics for numeric columns
df.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  3.743400e+04  3.743400e+04  3.743400e+04         37396.000000
# mean   4.277047e+17  2.025030e+13  1.726825e+08           270.079420
# std    5.060226e+17  0.000000e+00  1.892181e+08          1034.959329
# min    2.595000e+03  2.025030e+13  1.678000e+03             1.000000
# 25%    2.129623e+07  2.025030e+13  1.777536e+07             1.000000
# 50%    5.017925e+07  2.025030e+13  8.832629e+07             2.000000
# 75%    9.121962e+17  2.025030e+13  3.069967e+08            10.000000
# max    1.366910e+18  2.025030e+13  6.814365e+08          5255.000000
#
#        host_total_listings_count      latitude     longitude  accommodates  \
# count               37396.000000  37434.000000  37434.000000  37434.000000
# mean                  351.462349     40.728868    -73.947339      2.766576
# std                  1234.911395      0.056220      0.054872      1.908986
# min                     1.000000     40.500366    -74.251907      1.000000
# 25%                     1.000000     40.688670    -73.983459      2.000000
# 50%                     3.000000     40.726350    -73.955085      2.000000
# 75%                    14.000000     40.762480    -73.928438      4.000000
# max                  9055.000000     40.911390    -73.713650     16.000000
#
#           bathrooms      bedrooms  ...  review_scores_cleanliness  \
# count  22503.000000  31523.000000  ...               25646.000000
# mean       1.191308      1.374140  ...                   4.656908
# std        0.554629      0.925829  ...                   0.502644
# min        0.000000      0.000000  ...                   0.000000
# 25%        1.000000      1.000000  ...                   4.530000
# 50%        1.000000      1.000000  ...                   4.810000
# 75%        1.000000      2.000000  ...                   5.000000
# max       15.500000     15.000000  ...                   5.000000
#
#        review_scores_checkin  review_scores_communication  \
# count           25632.000000                 25641.000000
# mean                4.833810                     4.824749
# std                 0.379561                     0.412215
# min                 0.000000                     0.000000
# 25%                 4.820000                     4.820000
# 50%                 4.950000                     4.960000
# 75%                 5.000000                     5.000000
# max                 5.000000                     5.000000
#
#        review_scores_location  review_scores_value  \
# count            25629.000000         25630.000000
# mean                 4.743262             4.640219
# std                  0.394258             0.493066
# min                  0.000000             0.000000
# 25%                  4.650000             4.530000
# 50%                  4.850000             4.760000
# 75%                  5.000000             4.940000
# max                  5.000000             5.000000
#
#        calculated_host_listings_count  \
# count                    37434.000000
# mean                        69.169739
# std                        225.817395
# min                          1.000000
# 25%                          1.000000
# 50%                          2.000000
# 75%                          8.000000
# max                       1194.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                 37434.000000
# mean                                     48.619704
# std                                     211.988897
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                       2.000000
# max                                    1194.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                  37434.000000
# mean                                      18.809425
# std                                       86.388280
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        2.000000
# max                                      616.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                 37434.000000       25647.000000
# mean                                      0.012956           0.832412
# std                                       0.160868           1.853842
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.080000
# 50%                                       0.000000           0.270000
# 75%                                       0.000000           0.970000
# max                                       4.000000         117.980000
#
# [8 rows x 43 columns]

# %%
# Display basic statistics for object (categorical) columns
df.describe(include=['object'])
# Out:
#                                listing_url last_scraped       source  \
# count                                37434        37434        37434
# unique                               37434            2            2
# top     https://www.airbnb.com/rooms/36121     3/3/2025  city scrape
# freq                                     1        19480        22509
#
#                                   name  \
# count                            37432
# unique                           35726
# top     Water View King Bed Hotel Room
# freq                                30
#
#                                               description  \
# count                                               36441
# unique                                              31003
# top     Keep it simple at this peaceful and centrally-...
# freq                                                   94
#
#                                     neighborhood_overview  \
# count                                               20224
# unique                                              14933
# top     This furnished apartment is located in Midtown...
# freq                                                  113
#
#                                               picture_url  \
# count                                               37433
# unique                                              36629
# top     https://a0.muscache.com/pictures/6998e77e-4564...
# freq                                                   35
#
#                                            host_url   host_name  host_since  \
# count                                         37434       37396       37396
# unique                                        22284        8476        5142
# top     https://www.airbnb.com/users/show/107434423  Blueground  12/16/2016
# freq                                           1194        1194        1200
#
#         ...        room_type bathrooms_text  \
# count   ...            37434          37404
# unique  ...                4             31
# top     ...  Entire home/apt         1 bath
# freq    ...            20175          19284
#
#                                                 amenities     price  \
# count                                               37434     22308
# unique                                              30306      1022
# top     ["Air conditioning", "Carbon monoxide alarm", ...  $150.00
# freq                                                  253       376
#
#        has_availability calendar_last_scraped first_review last_review  \
# count             32057                 37434        25647       25647
# unique                2                     2         4337        3248
# top                   t              3/3/2025     1/1/2023   2/16/2025
# freq              31773                 19480           65         234
#
#        license instant_bookable
# count     5369            37434
# unique    2011                2
# top     Exempt                f
# freq      2814            29853
#
# [4 rows x 36 columns]

# %%
# Display sample rows
df.sample(5)
# Out:
#                  id                                       listing_url  \
# 32046  1.109440e+18  https://www.airbnb.com/rooms/1109440883056083759
# 6553   1.332825e+07             https://www.airbnb.com/rooms/13328254
# 32218  1.121100e+18  https://www.airbnb.com/rooms/1121098794146870631
# 24029  7.275230e+17   https://www.airbnb.com/rooms/727523095270280757
# 18414  4.931963e+07             https://www.airbnb.com/rooms/49319626
#
#           scrape_id last_scraped           source  \
# 32046  2.025030e+13     3/2/2025      city scrape
# 6553   2.025030e+13     3/3/2025  previous scrape
# 32218  2.025030e+13     3/2/2025      city scrape
# 24029  2.025030e+13     3/2/2025  previous scrape
# 18414  2.025030e+13     3/3/2025      city scrape
#
#                                                name  \
# 32046                       Close to Central Park 2
# 6553   Simple, Spacious Room in LES/Two Bridges Apt
# 32218                      626 10th ave-3bed 1 bath
# 24029  Lovely, cozy apartment in amenities building
# 18414                Large room 20 min to Manhattan
#
#                                              description  \
# 32046  This is a large studio apartment. Centrally lo...
# 6553   Spacious apartment lay-out in a fifth floor wa...
# 32218  You'll have a great time at this comfortable p...
# 24029  Take it easy at this unique and tranquil getaw...
# 18414  Enjoy of this quiet and central accommodation ...
#
#                                    neighborhood_overview  \
# 32046                                                NaN
# 6553   Lively and expanding Lower East Side neighborh...
# 32218                                                NaN
# 24029                                                NaN
# 18414                                                NaN
#
#                                              picture_url    host_id  ...  \
# 32046  https://a0.muscache.com/pictures/hosting/Hosti...  566262732  ...
# 6553   https://a0.muscache.com/pictures/76478ee1-915f...   20932025  ...
# 32218  https://a0.muscache.com/pictures/miso/Hosting-...   51501835  ...
# 24029  https://a0.muscache.com/pictures/miso/Hosting-...   15805343  ...
# 18414  https://a0.muscache.com/pictures/hosting/Hosti...  395015552  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 32046                        5.00                   5.00                3.00
# 6553                         5.00                   5.00                5.00
# 32218                        5.00                   5.00                5.00
# 24029                        5.00                   4.88                4.88
# 18414                        4.38                   4.83                4.50
#
#       license instant_bookable calculated_host_listings_count  \
# 32046     NaN                f                              8
# 6553      NaN                f                              1
# 32218     NaN                f                            176
# 24029     NaN                f                              2
# 18414     NaN                f                              3
#
#       calculated_host_listings_count_entire_homes  \
# 32046                                           8
# 6553                                            0
# 32218                                         176
# 24029                                           1
# 18414                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 32046                                            0
# 6553                                             1
# 32218                                            0
# 24029                                            1
# 18414                                            3
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 32046                                           0              0.21
# 6553                                            0              0.06
# 32218                                           0              0.11
# 24029                                           0              0.29
# 18414                                           0              0.63
#
# [5 rows x 79 columns]

# %%
# Display the last few rows
df.tail()
# Out:
#                  id                                       listing_url  \
# 37429  1.366330e+18  https://www.airbnb.com/rooms/1366333532374850165
# 37430  1.366720e+18  https://www.airbnb.com/rooms/1366717321390111215
# 37431  1.366720e+18  https://www.airbnb.com/rooms/1366721904709517353
# 37432  1.366720e+18  https://www.airbnb.com/rooms/1366722692755341871
# 37433  1.366720e+18  https://www.airbnb.com/rooms/1366723228243064949
#
#           scrape_id last_scraped       source                            name  \
# 37429  2.025030e+13     3/2/2025  city scrape  Beautiful 1-Bed Apt in Harlem!
# 37430  2.025030e+13     3/2/2025  city scrape  Private Room w/ Ensuite Bath H
# 37431  2.025030e+13     3/2/2025  city scrape          2 Bedroom on East Side
# 37432  2.025030e+13     3/2/2025  city scrape    Stylish 2Bd near Bryant Park
# 37433  2.025030e+13     3/2/2025  city scrape    Modern Private Room + Bath H
#
#                                              description  \
# 37429  Welcome to your temporary home in the vibrant ...
# 37430  Stylish Private Rooms w/ En-Suite Baths in Bro...
# 37431  Located in the Murray Hill area and occupies a...
# 37432  Enjoy everything the city has to offer while l...
# 37433  Stylish Private Rooms w/ En-Suite Baths in Bro...
#
#       neighborhood_overview  \
# 37429                   NaN
# 37430                   NaN
# 37431                   NaN
# 37432                   NaN
# 37433                   NaN
#
#                                              picture_url    host_id  ...  \
# 37429  https://a0.muscache.com/pictures/miso/Hosting-...   40019013  ...
# 37430  https://a0.muscache.com/pictures/miso/Hosting-...  483056418  ...
# 37431  https://a0.muscache.com/pictures/miso/Hosting-...   30283594  ...
# 37432  https://a0.muscache.com/pictures/miso/Hosting-...  407304997  ...
# 37433  https://a0.muscache.com/pictures/miso/Hosting-...  483056418  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 37429                         NaN                    NaN                 NaN
# 37430                         NaN                    NaN                 NaN
# 37431                         NaN                    NaN                 NaN
# 37432                         NaN                    NaN                 NaN
# 37433                         NaN                    NaN                 NaN
#
#       license instant_bookable calculated_host_listings_count  \
# 37429     NaN                f                              1
# 37430     NaN                f                             24
# 37431     NaN                f                             48
# 37432     NaN                t                             25
# 37433     NaN                f                             24
#
#       calculated_host_listings_count_entire_homes  \
# 37429                                           0
# 37430                                           0
# 37431                                          48
# 37432                                          25
# 37433                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 37429                                            1
# 37430                                           24
# 37431                                            0
# 37432                                            0
# 37433                                           24
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 37429                                           0               NaN
# 37430                                           0               NaN
# 37431                                           0               NaN
# 37432                                           0               NaN
# 37433                                           0               NaN
#
# [5 rows x 79 columns]

# %%
# Complete summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37434 entries, 0 to 37433
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            37434 non-null  float64
#  1   listing_url                                   37434 non-null  object
#  2   scrape_id                                     37434 non-null  float64
#  3   last_scraped                                  37434 non-null  object
#  4   source                                        37434 non-null  object
#  5   name                                          37432 non-null  object
#  6   description                                   36441 non-null  object
#  7   neighborhood_overview                         20224 non-null  object
#  8   picture_url                                   37433 non-null  object
#  9   host_id                                       37434 non-null  int64
#  10  host_url                                      37434 non-null  object
#  11  host_name                                     37396 non-null  object
#  12  host_since                                    37396 non-null  object
#  13  host_location                                 29747 non-null  object
#  14  host_about                                    21455 non-null  object
#  15  host_response_time                            21286 non-null  object
#  16  host_response_rate                            21286 non-null  object
#  17  host_acceptance_rate                          22740 non-null  object
#  18  host_is_superhost                             36994 non-null  object
#  19  host_thumbnail_url                            37396 non-null  object
#  20  host_picture_url                              37396 non-null  object
#  21  host_neighbourhood                            29718 non-null  object
#  22  host_listings_count                           37396 non-null  float64
#  23  host_total_listings_count                     37396 non-null  float64
#  24  host_verifications                            37396 non-null  object
#  25  host_has_profile_pic                          37396 non-null  object
#  26  host_identity_verified                        37396 non-null  object
#  27  neighbourhood                                 20225 non-null  object
#  28  neighbourhood_cleansed                        37434 non-null  object
#  29  neighbourhood_group_cleansed                  37434 non-null  object
#  30  latitude                                      37434 non-null  float64
#  31  longitude                                     37434 non-null  float64
#  32  property_type                                 37434 non-null  object
#  33  room_type                                     37434 non-null  object
#  34  accommodates                                  37434 non-null  int64
#  35  bathrooms                                     22503 non-null  float64
#  36  bathrooms_text                                37404 non-null  object
#  37  bedrooms                                      31523 non-null  float64
#  38  beds                                          22352 non-null  float64
#  39  amenities                                     37434 non-null  object
#  40  price                                         22308 non-null  object
#  41  minimum_nights                                37434 non-null  int64
#  42  maximum_nights                                37434 non-null  int64
#  43  minimum_minimum_nights                        37431 non-null  float64
#  44  maximum_minimum_nights                        37431 non-null  float64
#  45  minimum_maximum_nights                        37431 non-null  float64
#  46  maximum_maximum_nights                        37431 non-null  float64
#  47  minimum_nights_avg_ntm                        37431 non-null  float64
#  48  maximum_nights_avg_ntm                        37431 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              32057 non-null  object
#  51  availability_30                               37434 non-null  int64
#  52  availability_60                               37434 non-null  int64
#  53  availability_90                               37434 non-null  int64
#  54  availability_365                              37434 non-null  int64
#  55  calendar_last_scraped                         37434 non-null  object
#  56  number_of_reviews                             37434 non-null  int64
#  57  number_of_reviews_ltm                         37434 non-null  int64
#  58  number_of_reviews_l30d                        37434 non-null  int64
#  59  availability_eoy                              37434 non-null  int64
#  60  number_of_reviews_ly                          37434 non-null  int64
#  61  estimated_occupancy_l365d                     37434 non-null  int64
#  62  estimated_revenue_l365d                       22308 non-null  float64
#  63  first_review                                  25647 non-null  object
#  64  last_review                                   25647 non-null  object
#  65  review_scores_rating                          25647 non-null  float64
#  66  review_scores_accuracy                        25636 non-null  float64
#  67  review_scores_cleanliness                     25646 non-null  float64
#  68  review_scores_checkin                         25632 non-null  float64
#  69  review_scores_communication                   25641 non-null  float64
#  70  review_scores_location                        25629 non-null  float64
#  71  review_scores_value                           25630 non-null  float64
#  72  license                                       5369 non-null   object
#  73  instant_bookable                              37434 non-null  object
#  74  calculated_host_listings_count                37434 non-null  int64
#  75  calculated_host_listings_count_entire_homes   37434 non-null  int64
#  76  calculated_host_listings_count_private_rooms  37434 non-null  int64
#  77  calculated_host_listings_count_shared_rooms   37434 non-null  int64
#  78  reviews_per_month                             25647 non-null  float64
# dtypes: float64(25), int64(18), object(36)
# memory usage: 22.6+ MB
